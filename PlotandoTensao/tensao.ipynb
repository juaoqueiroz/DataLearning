# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vibration_data = pd.read_csv('DadosTensao.csv', "tensao")
vibration_data['tempo'] = data.index
vibration_data.to_csv('vibration_data.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 vibration_data = pd.read_csv('DadosTensao.csv')
# ----> 2 vibration_data['tempo'] = data.index
#       3 vibration_data.to_csv('vibration_data.csv', index = False)
#
# NameError: name 'data' is not defined

# %%
print(vibration_data)
# Out:
#          Untitled
# 0        0.032208
# 1        0.060254
# 2        0.034120
# 3        0.013404
# 4        0.012766
# ...           ...
# 1048570  0.027427
# 1048571  0.068540
# 1048572  0.051967
# 1048573  0.025196
# 1048574  0.015953
#
# [1048575 rows x 1 columns]

# %%
graf_linha = sns.lineplot(data = vibration_data, x = "tempo", y="Untitled", color = "red")
plt.show(graf_linha)

# %%
vibration_datawtime = pd.read_csv('DadosTensao.csv')
valor_inicial = 0
delta_t = 3.906250e-5
vibration_datawtime['Tempo'] = valor_inicial + (vibration_datawtime.index * delta_t)
vibration_datawtime.to_csv('vibration_datawtime', index = False)

# %%
graf_tensao = sns.lineplot(data = vibration_datawtime, x = "Tempo", y="Untitled", color = "red")
plt.show(graf_tensao)

# %%
sns.set(rc={'figure.figsize':(20.0,8.0)})
graf_tensao = sns.lineplot(data = vibration_datawtime, x = "Tempo", y="Untitled", color = "red")
plt.show(graf_tensao)

# %%
plt.figure(figsize=(20,8))
plt.plot(vibration_datawtime['Tempo'], vibration_datawtime['Untitled'])
